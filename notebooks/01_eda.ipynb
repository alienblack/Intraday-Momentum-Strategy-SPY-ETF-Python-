# %% [markdown]
# # SPY Intraday EDA
# Load intraday data, inspect gaps, and visualize VWAP/momentum before running backtests.

# %%
import pandas as pd
from src.data_loader import load_intraday

intraday = load_intraday('../data/spy_1min.csv')
intraday.head()
